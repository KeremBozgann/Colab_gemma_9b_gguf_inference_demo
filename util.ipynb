# %%
# %%bash
# set -euo pipefail
#
# # Optional utility for non-Ollama quantization workflows.
# python -m pip install -U bitsandbytes accelerate peft transformers

# %%
# %%bash
# set -euo pipefail
#
# # Optional cleanup utility for Google DriveFS cache directories.
# rm -rf ~/.config/Google/DriveFS/lost_and_found
# rm -rf ~/.config/Google/DriveFS/*/content_cache
